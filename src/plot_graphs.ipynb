# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
metrics = np.load('model_100/metrics.npy').item()

# %%
x_values = np.arange(1, len(metrics['train_loss']) + 1)

plt.figure(figsize = (12, 8))
plt.title('loss vs epoch')
plt.xlabel('epoch')
plt.ylabel('loss')

plt.plot(x_values, metrics['train_loss'], 'b--', label = 'u-net training loss')
plt.plot(x_values, metrics['valid_loss'], 'r--', label = 'u-net validation loss')

plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.title('accuracy vs epoch')
plt.xlabel('epoch')
plt.ylabel('accuracy')

plt.plot(x_values, metrics['valid_acc'], 'g--', label = 'u-net validation accuracy')

plt.legend(loc = 4)
plt.show()
